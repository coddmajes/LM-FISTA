# %% [markdown]
# # Plot Results for Unrolled Iterative Algorithms

# %%
import numpy as np
import tensorflow as tf
import pathlib
import matplotlib.pyplot as plt
# from matplotlib.font_manager import _rebuild
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import MultipleLocator

# _rebuild() #reload

from time import time
# print(tf.__version__)
# tf.keras.backend.set_floatx('float32')

makers = ["+--","+--","+--","+--","+--","+--","+--","+--","+--","+--","+--","+--",]
#makers = ["o--","<--","X--","s--","P--","o--","<--","X--","o--","<--","P--","x-","H-","P-"]
#makers = ["o--","<--","X--","s--","*--","P--","P--","x-","H-","P-"]
#makers = ["o--","<--","o--","<--","o--","<--","*--","P--","P--","x-","H-","P-"]
#co_p = [ 'red', 'red',"blue","blue","pink","purple","palegreen","camel"]
#co_p = ["purple",'green','blue', "blue","blue","pink","purple","palegreen","camel"]
#co_p = ['sandybrown', "white","white"]
#co_p = ['purple', 'sandybrown','sandybrown','steelblue','darkseagreen',]
#co_p = ['c', 'brown','green','purple',"navy","sandybrown","black"]

co_p = ['sandybrown', 'steelblue',"palevioletred","darkseagreen","gray","purple","blue","pink","purple","yellow","black"]
#co_p = ['purple', 'sandybrown','sandybrown','sandybrown','sandybrown',"green",'darkseagreen','blue','steelblue','steelblue',
        #"palevioletred",'palevioletred',"gray","gray","purple","blue","blue","pink","purple","palegreen","camel"]
#co_p = ['sandybrown', 'sandybrown','steelblue', 'steelblue',"darkseagreen","darkseagreen","gray","gray","purple","blue","blue","pink","purple","palegreen","camel"]
#co_p = ['sandybrown', 'sandybrown','sandybrown','steelblue','steelblue','steelblue', "darkseagreen",'darkseagreen','darkseagreen',"palevioletred","gray","gray","purple","blue","blue","pink","purple","palegreen","camel"]
#co_p = ['green', 'blue', "purple","pink","gray","gray","purple","blue","blue","pink","purple","palegreen","camel"]
title1, title2, title3, title4 = ["LISTA", "LISTA_cp", "TSS_LISTA_cp", "TSS_UISTA"]
test_titles = [title1, title2, title3, title4]
test_titles = ["Batch_Size_64","Batch_Size_256","Batch_Size_512","Batch_Size_1024", "Batch_Size_2048"]
layers = 16
colum=2
fsize=10
ymax=10
ymin=10
dire='upper right'
figsiz=(6,3)
ms=8
yspace=10
ylabel = 'NMSE(dB)'


def plot_contrast(in_x, in_tit):
    for i, mak, tit, x_,co_ in zip(np.arange(len(test_titles)), makers, test_titles, in_x,co_p):
        font = FontProperties(fname='/usr/share/fonts/truetype/arphic/uming.ttc')
        plt.plot(np.arange(layers), x_, mak,  color= co_,markersize=10,label=tit,linewidth=1.5) #mew=1,linewidth=1,
        #plt.plot(np.arange(layers), x_[0:10], mak,  color= co_,markerfacecolor= 'none',label=tit) #mew=1,linewidth=1,
        plt.xticks(np.arange(layers))
        plt.rcParams['figure.figsize'] = figsiz
        plt.tick_params(direction='in')
        plt.grid(ls='--')
        plt.ylim(ymin=ymin)
        plt.ylim(ymax=ymax)
        plt.xlabel('Iterations/Layers(k)',fontsize=12)
        #plt.xlabel(u'迭代次数/层数',fontproperties=font)
        plt.ylabel(ylabel,fontsize=12)
        #plt.ylabel('MSE')
        plt.title(in_tit)
        plt.grid(True, linestyle='-.')
        #plt.legend(ncol=colum, loc= 'lower left',fontsize=fsize)
        plt.legend(ncol=colum, loc= dire,fontsize=fsize, frameon=True, edgecolor='black',fancybox=False)
        #plt.legend(loc= 'upper right')
    plt.show()


def plot_d(in_x, label):
    for tit, mak, x_,co_ in zip(test_titles, makers, in_x,co_p):
        font = FontProperties(fname='/usr/share/fonts/truetype/arphic/uming.ttc')
        plt.plot(2+np.arange(layers), [x for x in x_], mak, color = co_, markerfacecolor= 'none',label=tit) #mew=1,linewidth=1,
        plt.xticks(2+np.arange(layers))
        
        plt.rcParams['figure.figsize'] = figsiz
        plt.xlabel('Number of iterations or layers (k)')
#         plt.xlabel(u'迭代次数/层数（k）',fontproperties=font)
        plt.ylim(ymin=ymin)
        plt.ylim(ymax=ymax)
        plt.grid(True, linestyle='-.')
        plt.ylabel(label,fontsize=16)
        plt.legend(ncol=colum, loc= dire,fontsize=fsize, frameon=True, edgecolor='black',fancybox=False)
        #plt.legend(ncol=1, loc= 'upper right',fontsize=9)
    plt.show()


def plot_(in_x, label):
    font = FontProperties(fname='/usr/share/fonts/truetype/arphic/uming.ttc')
    plt.plot(2+np.arange(layers), [x for x in in_x], "o--", color = "sandybrown") #mew=1,linewidth=1,
    plt.xticks(2+np.arange(layers))
    plt.rcParams['figure.figsize'] = (6, 3)
    #plt.rcParams['figure.figsize'] = (4, 2)
    plt.xlabel('Number of iterations or layers (k)')
    #plt.xlabel(u'迭代次数/层数(k)', fontproperties=font)
    plt.ylabel(label)
    plt.grid(True, linestyle='-.')
    #plt.legend(ncol=1, loc= 'upper right',fontsize=9)
    plt.show()


# def plot_d(in_x, label):
#     font = FontProperties(fname='/usr/share/fonts/truetype/arphic/uming.ttc')
#     for tit, mak, x_,co_ in zip(test_titles, makers, in_x,co_p):
#         plt.plot(1+np.arange(layers), [x for x in in_x], "o--", color = "sandybrown") #mew=1,linewidth=1,
#         plt.xticks(1+np.arange(layers))
#         plt.rcParams['figure.figsize'] = (6, 3)
#         plt.xlabel('Number of iterations or layers (k)')
#         #plt.xlabel(u'迭代次数/层数(k)', fontproperties=font)
#         plt.ylabel(label)
#         #plt.legend(ncol=1, loc= 'upper right',fontsize=9)
#     plt.show()

# %% [markdown]
# ## V1-verification of different weight design: shared, unshared and tied
#
# LISTA(shared), LISTA(tied), LISTA(unshared), LAMP(shared), LAMP(tied)
#
# basic setting: $\lambda$=0.4, batch_size=64, validation data: 1000, test data: 1000, SNR=inf

# %% [markdown]
# ### V1-1: comparison between LISTA(shared),LISTA(unshared), LISTA(tied),  LAMP(unshared), LAMP(tied)

# %%
# LISTA(shared)
x_listashare4 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_en_de_T16_lam0.4_naFalse_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USFalse_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listashare4.append(d)

# LISTA(unshared)
x_listanotshare4 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_en_de_T16_lam0.4_naFalse_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listanotshare4.append(d)
    
# LISTA(tied)
x_lista16share4 = [0.0]  #LISTA-A
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_en_de_T16_lam0.4_naFalse_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lista16share4.append(d)
    
# LAMP(unshared)
x_lampnotshare4 = [0.0]
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LAMP_en_de_ssFalse_T16_lam0.4_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lampnotshare4.append(d)
    
# LAMP(tied)
x_lamp4 = [0.0]
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LAMP_en_de_ssFalse_T16_lam0.4_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lamp4.append(d)

# %%
co_p = ['red', 'brown',"orange","green","cyan","dodgerblue",
        "crimson","navy",]
#co_p = ['red', 'black',"darkorange","lawngreen","cyan","dodgerblue",
#        "crimson","navy",]

makers = [".-",".-",".-",".-",".-",".-"]
colum=2
fsize=12
ymax=2
ymin=-55
figsiz = (8,6)
dire='lower left'
ms=15


test_titles = ["LISTA(shared)","LISTA(unshared)", "LISTA(tied)","LAMP(unshared)","LAMP(tied)",
              ]
layers = 17
xh_ = [x_listashare4,x_listanotshare4, x_lista16share4,x_lampnotshare4,x_lamp4,
       ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V1-2: validation for different types of weights design

# %%
# LISTA_2
x_lista2share4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_en_de_T16_lam0.4_naFalse_en_deFalse_nums2_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lista2share4.append(d)

# LISTA_4
x_lista4share4 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_en_de_T16_lam0.4_naFalse_en_deFalse_nums4_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lista4share4.append(d)
    
# LISTA_8
x_lista8share4 = [0.0]
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_en_de_T16_lam0.4_naFalse_en_deFalse_nums8_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lista8share4.append(d)

# %%
co_p = ['red', 'brown',"orange","green","cyan","dodgerblue",
        "crimson","navy",]
#co_p = ['red', 'black',"darkorange","lawngreen","cyan","dodgerblue",
#        "crimson","navy",]

makers = [".-",".-",".-",".-",".-",".-"]
colum=2
fsize=12
ymax=2
ymin=-42
figsiz = (8,6)
dire='upper right'
ms=15


test_titles = ["LISTA","LISTA-1", "LISTA-2","LISTA-4","LISTA-8","LISTA-16",
              ]
layers = 17
xh_ = [x_listashare4,x_listanotshare4, x_lista2share4,x_lista4share4,x_lista8share4,x_lista16share4,
       ]
plot_contrast(xh_, "")

# %% [markdown]
# ## V2, verification of adding Nesterov's acceleration
#
# LISTA(tied), LISTA-CP, ALISTA,and proposed LsLISTA;
#
# (-NA means Nesterov's acceleration is added)
#
# basic setting: $\lambda$=0.4, batch_size=64, validation data: 1000, test data: 1000

# %% [markdown]
# ### V2-1: LISTA(tied), LISTA(tied)-NA, LISTA-CP, LISTA-CP-NA, ALISTA, ALISTA-NA, LsLISTA, LsLISTA-NA, SNR=inf

# %%
# LISTA(tied)-NA
x_listana4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_en_de_T16_lam0.4_naTrue_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listana4.append(d)

# LISTA-CP
x_listacpnotshare4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_CP_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listacpnotshare4.append(d)

# LISTA-CP-NA
x_listacpna4 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_CP_en_de_ssFalse_T16_lam0.4_naTrue_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listacpna4.append(d)

# ALISTA
x_alista4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/ALISTA_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_alista4.append(d)

# ALISTA-NA
x_alistana4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/ALISTA_en_de_ssFalse_T16_lam0.4_naTrue_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_alistana4.append(d)

# LsLISTA
x_lslista164 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LsLISTA_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lslista164.append(d)

# LsLISTA-NA
x_lslistana4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LsLISTA_en_de_ssFalse_T16_lam0.4_naTrue_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lslistana4.append(d)

# %%
# co_p = ['brown','brown','darkorange','darkorange','gold','gold',
#         "darkgreen","darkgreen",]
# makers =["+-",".-",
#          "+-",".-","+-",".-","+-",".-","+--","+--","+--","+--","+--","+--",".--","+--"]
co_p = ['red', 'red', 'black','black',"lawngreen","lawngreen","dodgerblue","dodgerblue","cyan","dodgerblue",
        "crimson","navy",]
#co_p = ['red', 'black',"darkorange","lawngreen","cyan","dodgerblue",
#        "crimson","navy",]

makers = [".-.","+-.",".-.","+-.",".-.","+-.",".-.","+-.",".-",".-"]
ymax=2
ymin=-65

colum=2
fsize=12
figsiz = (8,6)
dire='lower left'
ms=12

test_titles = ["LISTA(tied)", "LISTA(tied)-NA","LISTA-CP","LISTA-CP-NA",
               "ALISTA","ALISTA-NA",
               "LsLISTA","LsLISTA-NA",
              ]
layers = 17
xh_ = [x_lista16share4,x_listana4, x_listacpnotshare4,x_listacpna4,
       x_alista4,x_alistana4,
      x_lslista164,x_lslistana4,
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V2-2: LISTA(tied), LISTA(tied)-NA, LISTA-CP, LISTA-CP-NA, ALISTA, ALISTA-NA, LsLISTA, LsLISTA-NA, SNR=20

# %%
# LISTA(tied)
x_lista420 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LISTA_en_de_T16_lam0.4_naFalse_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USFalse_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lista420.append(d)

# LISTA(tied)-NA
x_listana420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LISTA_en_de_T16_lam0.4_naTrue_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listana420.append(d)

# LISTA-CP
x_listacp420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LISTA_CP_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums1_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listacp420.append(d)

# LISTA-CP-NA
x_listacpna420 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LISTA_CP_en_de_ssFalse_T16_lam0.4_naTrue_en_deFalse_nums1_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listacpna420.append(d)

# ALISTA
x_alista420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/ALISTA_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_alista420.append(d)

# ALISTA-NA
x_alistana420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/ALISTA_en_de_ssFalse_T16_lam0.4_naTrue_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_alistana420.append(d)

# LsLISTA
x_lslista16420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LsLISTA_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lslista16420.append(d)

# LsLISTA-NA
x_lslistana420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LsLISTA_en_de_ssFalse_T16_lam0.4_naTrue_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lslistana420.append(d)

# %%
# co_p = ['brown','brown','darkorange','darkorange','gold','gold',
#         "darkgreen","darkgreen",]
# makers =["+-",".-",
#          "+-",".-","+-",".-","+-",".-","+--","+--","+--","+--","+--","+--",".--","+--"]
co_p = ['red', 'red', 'black','black',"lawngreen","lawngreen","dodgerblue","dodgerblue","cyan","dodgerblue",
        "crimson","navy",]
#co_p = ['red', 'black',"darkorange","lawngreen","cyan","dodgerblue",
#        "crimson","navy",]

makers = [".-.","+-.",".-.","+-.",".-.","+-.",".-.","+-.",".-",".-"]
ymax=2
ymin=-45

colum=2
fsize=12
figsiz = (8,6)
dire='best'
ms=12

test_titles = ["LISTA(tied)", "LISTA(tied)-NA","LISTA-CP","LISTA-CP-NA",
               "ALISTA","ALISTA-NA",
               "LsLISTA","LsLISTA-NA",
              ]
layers = 17
xh_ = [x_lista420,x_listana420, x_listacp420,x_listacpna420,
       x_alista420,x_alistana420,
      x_lslista16420,x_lslistana420,
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ## V3, validation of gamma, which is the learnable parameter for LMFISTA:

# %%
#LM-LISTA-CP
layers = 15
#INF
gammas_lmlistacp = []

for i in range(16):
    aa = np.load("./1210-test results/simulation_en_de0219/experiments/en_deFalse40/LM_FISTA_cp_en_de_ssFalse_T16_lam0.4_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0/" + str(i) + ".npy",allow_pickle=True).item()
    for k, d in aa.items ():
        #print(k)
        for j in range(i+1):
            if k.startswith( "LM_FISTA_cp_en_de" + str(j) + "/gamma"):
                print(d)
                gammas_lmlistacp.append(d*1.0)
                
plot_(gammas_lmlistacp, r'$LM_LFISTA-\gamma$')
# Out:
# 2022-04-29 21:58:07.550603: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.3738087>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7786636>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.8649892>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7927687>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.80570984>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.80957305>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7788384>
# ...

# %%
#LM_ALISTA
layers = 15
#INF
gammas_lmalista = []

for i in range(16):
    aa = np.load("./1210-test results/simulation_en_de0219/experiments/en_deFalse40/LM_ALISTA_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0/" + str(i) + ".npy",allow_pickle=True).item()
    for k, d in aa.items ():
        #print(k)
        for j in range(i+1):
            if k.startswith( "LM_ALISTA_en_de" + str(j) + "/gamma"):
                print(d)
                gammas_lmalista.append(d*1.0)
                
plot_(gammas_lmalista, r'$LM_LFISTA-\gamma$')
# Out:
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.42929676>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=1.0686208>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.86377066>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.8562169>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.77320606>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7981596>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7929234>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.78176033>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7742802>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7589824>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7772926>
# ...

# %%
#LMFISTA
layers = 15
#INF
gammas_lmfista = []

for i in range(16):
    aa = np.load("./1210-test results/simulation_en_de0219/experiments/en_deFalse40/LM_FISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0/" + str(i) + ".npy",allow_pickle=True).item()
    for k, d in aa.items ():
        #print(k)
        for j in range(i+1):
            if k.startswith( "LM_FISTA_en_de" + str(j) + "/gamma"):
                print(d)
                gammas_lmfista.append(d*1.0)
                
plot_(gammas_lmfista, r'$LM-LFISTA-\gamma$')
# Out:
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.40817407>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=1.0718063>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.86347747>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.85457414>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.8379607>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.8195031>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7959454>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.76647705>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7757831>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.78042704>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.7827079>
# ...

# %%
#LM-LISTA-CP-ss
layers = 15
#INF
gammas_lmlistacpss = []

for i in range(16):
    aa = np.load("./1210-test results/simulation_en_de0219/experiments/en_deFalse40/LM_FISTA_cp_en_de_ssTrue_T16_lam0.4_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0/" + str(i) + ".npy",allow_pickle=True).item()
    for k, d in aa.items ():
        #print(k)
        for j in range(i+1):
            if k.startswith( "LM_FISTA_cp_en_de" + str(j) + "/gamma"):
                print(d)
                gammas_lmlistacpss.append(d*1.0)
                
plot_(gammas_lmlistacpss, r'$LM_LFISTA-\gamma$')
# Out:
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.20225126>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.23891424>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.2274391>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.24543397>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.23673426>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.24928018>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.24268566>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.24354771>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.23768838>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.23947701>
# <tf.Variable 'LM_FISTA_cp_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.24121782>
# ...

# %%
#LM_ALISTA_ss
layers = 15
#INF
gammas_lmalistass = []

for i in range(16):
    aa = np.load("./1210-test results/simulation_en_de0219/experiments/en_deFalse40/LM_ALISTA_en_de_ssTrue_T16_lam0.4_naFalse_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0/" + str(i) + ".npy",allow_pickle=True).item()
    for k, d in aa.items ():
        #print(k)
        for j in range(i+1):
            if k.startswith( "LM_ALISTA_en_de" + str(j) + "/gamma"):
                print(d)
                gammas_lmalistass.append(d*1.0)
                
plot_(gammas_lmalistass, r'$LM_LFISTA-\gamma$')
# Out:
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.20263846>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.22954884>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.2158181>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.19226648>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.22548091>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.1789387>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.17637576>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.17727095>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.16442883>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.16001403>
# <tf.Variable 'LM_ALISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=-0.15872297>
# ...

# %%
#LMFISTA-ss
layers = 15
#INF
gammas_lmfistass = []

for i in range(16):
    aa = np.load("./1210-test results/simulation_en_de0219/experiments/en_deFalse40/LM_FISTA_en_de_ssTrue_T16_lam0.4_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0/" + str(i) + ".npy",allow_pickle=True).item()
    for k, d in aa.items ():
        #print(k)
        for j in range(i+1):
            if k.startswith( "LM_FISTA_en_de" + str(j) + "/gamma"):
                print(d)
                gammas_lmfistass.append(d*1.0)
                
plot_(gammas_lmfistass, r'$LM-LFISTA-\gamma$')
# Out:
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.17409796>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.38255277>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.4599919>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.4914573>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.46329483>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.48456267>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.48745933>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.4809042>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.4448067>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.416611>
# <tf.Variable 'LM_FISTA_en_de1/gamma_1:0' shape=() dtype=float32, numpy=0.39344567>
# ...

# %%
ks =1.0
Ks = []
layers = 15
for _ in range(15):
    k = (1. + tf.math.sqrt(1. + 4. * ks * ks))/2
    Ks.append((ks-1)/k)
    ks = k
plot_(Ks, r'$LM_LFISTA-\gamma$')

# %%
test_titles = ["LM-LISTA-CP","LM-ALISTA","LM-FISTA",
               "LM-LISTA-CPss","LM-ALISTA-ss","LM-FISTA-ss",r'$\frac{t_{(k)}-1}{t_{(k+1)}}$',]
co_p = ["black","cyan",'r',"black","cyan",'g','b', 'gold',"purple","black",'navy',"darkgreen",'darkgreen',"c"]
makers = [".-",".-",".-",">-",
          ">-",">-",".-","+-","2-","+-","+--","x--",".--","+--"]
layers =15
colum=3
fsize=12
ymax = 1.5
ymin = -0.5
figsiz = (8,5)
dire='upper right'
ms=15
plot_d([gammas_lmlistacp,gammas_lmalista,gammas_lmfista,
        gammas_lmlistacpss,gammas_lmalistass, gammas_lmfistass,Ks], r'$\gamma$ / $\frac{t_{(k)}-1}{t_{(k+1)}}$')

# %% [markdown]
# ## V4, comparison between traditional iterative algorithms and proposed unrolled algorithms:

# %% [markdown]
# ### V3-1, ISTA, FISTA, TsLISTA, LsLISTA, LMFISTA SNR=inf

# %%
# ISTA
x_ista4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/ISTA_en_de_T16_lam0.4_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USFalse_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_ista4.append(d)

# FISTA
x_fista4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/FISTA_en_de_T16_lam0.4_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USFalse_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_fista4.append(d)

# TsLISTA
x_tslista14 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/TsLISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_tslista14.append(d)

# LMFISTA
x_lmfista4 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LM_FISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lmfista4.append(d)

# %%
co_p = ['black','black','green','blue',"red",]
makers = ["+--",".--",".-.",".-.",".-.",".--","+--",".--","+--"]
colum=2
fsize=12
ymax=2
ymin=-60
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["ISTA","FISTA","TsLISTA","LsLISTA","LMFISTA"
              ]
layers = 17
xh_ = [x_ista4,x_fista4,x_tslista14,x_lslista164,x_lmfista4
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V4-2, ISTA, FISTA, TsLISTA, LsLISTA, LMFISTA SNR=20

# %%
# ISTA
x_ista420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/ISTA_en_de_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USFalse_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_ista420.append(d)

#FISTA
x_fista420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/FISTA_en_de_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USFalse_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_fista420.append(d)

# TsLISTA
x_tslista420 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/TsLISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums1_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_tslista420.append(d)

# LMFISTA
x_lmfista420 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LM_FISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lmfista420.append(d)

# %%
co_p = ['black','black','green','blue',"red",]
makers = ["+--",".--",".-.",".-.",".-.",".--","+--",".--","+--"]
colum=2
fsize=12
ymax=2
ymin=-45
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["ISTA","FISTA","TsLISTA","LsLISTA","LMFISTA"
              ]
layers = 17
xh_ = [x_ista420,x_fista420,x_tslista420,x_lslista16420,x_lmfista420
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V4-3, ISTA, FISTA, TsLISTA, LsLISTA, LMFISTA SNR=10

# %%
# ISTA
x_ista410 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue10/ISTA_en_de_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR10_M250_N500_USFalse_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_ista410.append(d)


#FISTA
x_fista410 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue10/ISTA_en_de_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR10_M250_N500_USFalse_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_fista410.append(d)
    
    
# TsLISTA
x_tslista410 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue10/TsLISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums1_noiseTrue_SNR10_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_tslista410.append(d)
    

#LsLISTA
x_lslista16410 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue10/LsLISTA_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums16_noiseTrue_SNR10_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lslista16410.append(d)

# LMFISTA
x_lmfista410 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue10/LM_FISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR10_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lmfista410.append(d)

# %%
co_p = ['black','black','green','blue',"red",]
makers = ["+--",".--",".-.",".-.",".-.",".--","+--",".--","+--"]
colum=2
fsize=12
ymax=2
ymin=-27
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["ISTA","FISTA","TsLISTA","LsLISTA","LMFISTA"
              ]
layers = 17
xh_ = [x_ista410,x_fista410,x_tslista410,x_lslista16410,x_lmfista410
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ## V5, comparison between benchmark algorithm LISTA(tied),  LAMP(tied), and proposed unrolled algorithms:

# %% [markdown]
# ### V5-1, LISTA(tied), LAMP(tied), TsLISTA, LsLISTA, LMFISTA SNR=inf

# %%
# LAMP
x_lamp4 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LAMP_en_de_ssFalse_T16_lam0.4_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lamp4.append(d)

# %%
co_p = ['black','brown','green','blue',"red",]
makers = [".-.",".-.",".-.",".-.",".-.",".--","+--",".--","+--"]
colum=2
fsize=12
ymax=2
ymin=-60
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["LISTA(tied)","LAMP(tied)","TsLISTA","LsLISTA","LMFISTA"
              ]
layers = 17
xh_ = [x_lista16share4,x_lamp4,x_tslista14,x_lslista164,x_lmfista4
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V5-2, LISTA(tied), LAMP(tied), TsLISTA, LsLISTA, LMFISTA SNR=20

# %%
# LAMP
x_lamp420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LAMP_en_de_ssFalse_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lamp420.append(d)

# %%
co_p = ['black','brown','green','blue',"red",]
makers = [".-.",".-.",".-.",".-.",".-.",".--","+--",".--","+--"]
colum=2
fsize=12
ymax=2
ymin=-45
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["LISTA(tied)","LAMP(tied)","TsLISTA","LsLISTA","LMFISTA"
              ]
layers = 17
xh_ = [x_lista420,x_lamp420,x_tslista420,x_lslista16420,x_lmfista420
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V5-3, LISTA(tied), LAMP(tied), TsLISTA, LsLISTA, LMFISTA SNR=10

# %%
# LISTA(tied)
x_lista410 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue10/LISTA_en_de_T16_lam0.4_naFalse_en_deFalse_nums16_noiseTrue_SNR10_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lista410.append(d)

# LAMP
x_lamp410 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue10/LAMP_en_de_ssFalse_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR10_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lamp410.append(d)

# %%
co_p = ['black','brown','green','blue',"red",]
makers = [".-.",".-.",".-.",".-.",".-.",".--","+--",".--","+--"]
colum=2
fsize=12
ymax=2
ymin=-25
figsiz = (8,6)
dire='upper right'
ms=15

test_titles = ["LISTA(tied)","LAMP(tied)","TsLISTA","LsLISTA","LMFISTA"
              ]
layers = 17
xh_ = [x_lista410,x_lamp410,x_tslista410,x_lslista16410,x_lmfista410
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ## V6, comparison between weight coupling & analytical weight and proposed unrolled algorithms:

# %% [markdown]
# ### V6-1, LISTA-CP, TiLISTA, ALISTA, TsLISTA, LsLISTA, LMFISTA SNR=inf

# %%
# LISTA-CP
x_listacpnotshare4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_CP_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listacpnotshare4.append(d)

# TiLISTA    
x_tilista4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/TiLISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_tilista4.append(d)

# %%
co_p = ['black','brown',"y", 'green','blue',"red",]
makers = [".-.",".-.",".-.",".-.",".-.",".-.","+--",".--","+--"]
colum=2
fsize=12
ymax=2
ymin=-60
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["LISTA_CP","TiLISTA","ALISTA", "TsLISTA","LsLISTA","LMFISTA"
              ]
layers = 17
xh_ = [x_listacpnotshare4,x_tilista4, x_alista4,x_tslista14,x_lslista164,x_lmfista4
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V6-2, LISTA-CP, TiLISTA, ALISTA, TsLISTA, LsLISTA, LMFISTA SNR=20

# %%
# LISTA-CP
x_listacp420 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LISTA_CP_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums1_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listacp420.append(d)
    
# TiLISTA    
x_tilista420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/TiLISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_tilista420.append(d)

# %%
co_p = ['black','brown',"y", 'green','blue',"red",]
makers = [".-.",".-.",".-.",".-.",".-.",".-.","+--",".--","+--"]
colum=2
fsize=12
ymax=2
ymin=-45
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["LISTA_CP","TiLISTA","ALISTA", "TsLISTA","LsLISTA","LMFISTA"
              ]
layers = 17
xh_ = [x_listacp420,x_tilista420,x_alista420, x_tslista420,x_lslista16420,x_lmfista420
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V6-3, LISTA-CP-ss, TiLISTA-ss, ALISTA-ss, LsLISTA-ss, LMFISTA-ss SNR=inf

# %%
# LISTA-CP-ss
x_listacpss4 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LISTA_CP_en_de_ssTrue_T16_lam0.4_naFalse_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listacpss4.append(d)

    
# TiLISTA-ss
x_tilistass4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/TiLISTA_en_de_ssTrue_T16_lam0.4_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_tilistass4.append(d)

# ALISTA-ss
x_alistass4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/ALISTA_en_de_ssTrue_T16_lam0.4_naFalse_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_alistass4.append(d)
  
# LsLISTA-ss
x_lslistass4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LsLISTA_en_de_ssTrue_T16_lam0.4_naFalse_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lslistass4.append(d)

    
# LMFISTA-ss
x_lmfistass4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LM_FISTA_en_de_ssTrue_T16_lam0.4_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lmfistass4.append(d)

# %%
co_p = ['black','brown',"y", 'blue',"red",]
makers = [".-.",".-.",".-.",".-.",".-.",".-.","+--",".--","+--"]
colum=2
fsize=12
ymax=2
ymin=-80
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["LISTA-CP-ss","TiLISTA-ss","ALISTA-ss", "LsLISTA-ss","LMFISTA-ss"
              ]
layers = 17
xh_ = [x_listacpss4,x_tilistass4, x_alistass4,x_lslistass4,x_lmfistass4
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V6-4, LISTA-CP-ss, TiLISTA-ss, ALISTA-ss, LsLISTA-ss, LMFISTA-ss SNR=20

# %%
# LISTA-CP-ss
x_listacpss420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LISTA_CP_en_de_ssTrue_T16_lam0.4_naFalse_en_deFalse_nums1_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_listacpss420.append(d)

    
# TiLISTA-ss
x_tilistass420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/TiLISTA_en_de_ssTrue_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_tilistass420.append(d)

# ALISTA-ss
x_alistass420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/ALISTA_en_de_ssTrue_T16_lam0.4_naFalse_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_alistass420.append(d)
  
# LsLISTA-ss
x_lslistass420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LsLISTA_en_de_ssTrue_T16_lam0.4_naFalse_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lslistass420.append(d)

    
# LMFISTA-ss
x_lmfistass420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LM_FISTA_en_de_ssTrue_T16_lam0.4_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lmfistass420.append(d)

# %%
co_p = ['black','brown',"y", 'blue',"red",]
makers = [".-.",".-.",".-.",".-.",".-.",".-.","+--",".--","+--"]
colum=2
fsize=12
ymax=2
ymin=-50
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["LISTA-CP-ss","TiLISTA-ss","ALISTA-ss", "LsLISTA-ss","LMFISTA-ss"
              ]
layers = 17
xh_ = [x_listacpss420,x_tilistass420, x_alistass420,x_lslistass420,x_lmfistass420
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ## V7, comparison between accelerations or gain added and proposed LMFISTA:

# %% [markdown]
# ### V6-1, LFISTA, GLISTA, LMFISTA, SNR=inf

# %%
# LFISTA
x_lfista14 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LFISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lfista14.append(d)

# GLISTA
x_glista4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/GLISTA_en_de_ssTrue_T16_lam0.4_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_glista4.append(d)

# %%
co_p = ['black','blue',"red",]
makers = [".-.",".-.",".-.",".-.",".-.",".-.","+--",".--","+--"]
colum=3
fsize=12
ymax=2
ymin=-65
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["LFISTA","GLISTA-exp","LMFISTA"
              ]
layers = 17
xh_ = [x_lfista14,x_glista4, x_lmfista4
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V7-2, LFISTA, GLISTA, LMFISTA, SNR=20

# %%
# LFISTA
x_lfista1420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LFISTA_en_de_ssFalse_T16_lam0.4_en_deFalse_nums1_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lfista1420.append(d)
    
# GLISTA   
x_glista420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/GLISTA_en_de_ssTrue_T16_lam0.4_en_deFalse_nums1_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_glista420.append(d)

# %%
co_p = ['black','blue',"red",]
makers = [".-.",".-.",".-.",".-.",".-.",".-.","+--",".--","+--"]
colum=3
fsize=12
ymax=2
ymin=-50
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["LFISTA","GLISTA-exp","LMFISTA"
              ]
layers = 17
xh_ = [x_lfista1420,x_glista420, x_lmfista420
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ## V8, comparison between having learned momentum added and without:

# %% [markdown]
# ### V8-1, LISTA-CP, LM-LISTA-CP, ALISTA, LM-ALISTA, LsLISTA, LMFISTA, SNR=inf

# %%
# LM-LISTA-CP
x_lmfistacp4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LM_FISTA_cp_en_de_ssFalse_T16_lam0.4_en_deFalse_nums1_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lmfistacp4.append(d)

# LM-ALISTA
x_lmalista4 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deFalse40/LM_ALISTA_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums16_noiseFalse_SNR40_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lmalista4.append(d)

# %%
co_p = ['black','black','blue','blue',"red", "red",]
makers = [".-.","+-",".-.","+-",".-.","+-","+-","+--",".--","+--"]
colum=3
fsize=12
ymax=2
ymin=-68
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["LISTA-CP","LM-LISTA-CP", "ALISTA", "LM-ALISTA", "LsLISTA","LMFISTA"
              ]
layers = 17
xh_ = [x_listacpnotshare4, x_lmfistacp4,x_alista4, x_lmalista4, x_lslista164,  x_lmfista4, 
      ]
plot_contrast(xh_, "")

# %% [markdown]
# ### V8-1, LISTA-CP, LM-LISTA-CP, ALISTA, LM-ALISTA, LsLISTA, LMFISTA, SNR=20

# %%
# LM-LISTA-CP
x_lmfistacp420 = [0.0] 
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LM_FISTA_cp_en_de_ssFalse_T16_lam0.4_en_deFalse_nums1_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lmfistacp420.append(d)

# LM-ALISTA
x_lmalista420 = [0.0]  
for k, d in (np.load("./1210-test results/simulation_en_de0219/results/en_deTrue20/LM_ALISTA_en_de_ssFalse_T16_lam0.4_naFalse_en_deFalse_nums16_noiseTrue_SNR20_M250_N500_USTrue_exp0.npy",
                     allow_pickle=True).item()).items ():
    #print(d)
    x_lmalista420.append(d)

# %%
co_p = ['black','black','blue','blue',"red", "red",]
makers = [".-.","+-",".-.","+-",".-.","+-","+-","+--",".--","+--"]
colum=3
fsize=12
ymax=2
ymin=-50
figsiz = (8,6)
dire='lower left'
ms=15

test_titles = ["LISTA-CP","LM-LISTA-CP", "ALISTA", "LM-ALISTA", "LsLISTA","LMFISTA"
              ]
layers = 17
xh_ = [x_listacp420, x_lmfistacp420, x_alista420, x_lmalista420, x_lslista16420,x_lmfista420 
      ]
plot_contrast(xh_, "")
